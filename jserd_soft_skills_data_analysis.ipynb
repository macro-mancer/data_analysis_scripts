# %% [markdown]
# <a href="https://colab.research.google.com/github/macro-mancer/data_analysis_scripts/blob/main/jserd_soft_skills_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install package that is not available on Google Colab
# !pip install dython

# %%
import statistics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dython.nominal import associations

# %% [markdown]
# ### Loading Data from Job Descriptions:

# %%
#if using outside google colab, provide path to the csv file
soft_skills_br = pd.read_csv("/content/soft_skills_data_br.csv", sep=",")
soft_skills_br = soft_skills_br.drop(["text", "ID"], axis="columns")

soft_skills_br.head()
# Out:
#                                                title         org_name  \
# 0                                     Analista de QA            EXAME
# 1  ANALISTA DE TESTES JÚNIOR - ATUAÇÃO REMOTA OU ...          Fortics
# 2                                  QA Pleno (Remoto)  Beyond Soluções
# 3           Analista da Garantia da Qualidade Júnior              EMS
# 4                             Development QA Analyst            Kokku
#
#      seniority                                        hard_skills  \
# 0    Mid-level  ["test script", "customer insight", "API", "co...
# 1  Entry level  ["software quality", "quality assurance", "sof...
# 2    Mid-level   ["android studio", "azure devops", "visual art"]
# 3  Entry level  ["job description", "quality assurance", "good...
# 4  Entry level  ["quality assurance", "quality assurance", "te...
#
#                                          soft_skills company_size
# 0  ['Collaboration', 'Analytical', 'Organization'...        Large
# ...

# %%
#if using outside google colab, provide path to the csv file
soft_skills_us = pd.read_csv("/content/soft_skills_data_us.csv", sep=",")
soft_skills_us = soft_skills_us.drop(["text", "ID"], axis="columns")

soft_skills_us.head()
# Out:
#                                                title  \
# 0  Quality Assurance/Quality Control (QA/QC) Analyst
# 1  Quality Assurance/Quality Control (QA/QC) Analyst
# 2                                 Tester /QA Analyst
# 3                           Quality Assurance Tester
# 4                         QA Manual Tester, FULLTIME
#
#                     org_name    seniority  \
# 0         LaBella Associates  Entry level
# 1         LaBella Associates  Entry level
# 2  Donato Technologies, Inc.       Senior
# 3             Insight Global    Mid-level
# 4    Conch Technologies, Inc    Mid-level
#
#                                          hard_skills  \
# 0  ["quality assurance", "quality control", "prog...
# 1  ["quality assurance", "quality control", "prog...
# 2  ["job description", "verbal communication skil...
# 3  ["test case", "user story", "hp quality center...
# 4  ["manual testing", "computer science", "softwa...
#
# ...

# %% [markdown]
# ### Checking Data

# %%
soft_skills_br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2164 entries, 0 to 2163
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         2164 non-null   object
#  1   org_name      2164 non-null   object
#  2   seniority     2164 non-null   object
#  3   hard_skills   2164 non-null   object
#  4   soft_skills   2164 non-null   object
#  5   company_size  2164 non-null   object
# dtypes: object(6)
# memory usage: 101.6+ KB

# %%
soft_skills_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1658 entries, 0 to 1657
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1658 non-null   object
#  1   org_name      1658 non-null   object
#  2   seniority     1658 non-null   object
#  3   hard_skills   1658 non-null   object
#  4   soft_skills   1658 non-null   object
#  5   company_size  1657 non-null   object
# dtypes: object(6)
# memory usage: 77.8+ KB

# %% [markdown]
# #### Looking at an Overview of the Job Descriptions from Brazilian Companies

# %%
soft_skills_br["seniority"].value_counts()
# Out:
# seniority
# Entry level      845
# Not mentioned    582
# Mid-level        537
# Senior           200
# Name: count, dtype: int64

# %%
soft_skills_br["company_size"].value_counts()
# Out:
# company_size
# Large     1099
# Medium     418
# Micro      351
# Small      296
# Name: count, dtype: int64

# %%
soft_skills_br["soft_skills"].value_counts()
# Out:
# soft_skills
# ['Not mention']                                                                                186
# ['Communication (generic)']                                                                    105
# ['Planning']                                                                                    70
# ['Collaboration']                                                                               39
# ['Innovation', 'Communication (generic)']                                                       37
#                                                                                               ...
# ['Creativity', 'Leadership', 'Investigative', 'Team', 'Interpersonal']                           1
# ['Innovation', 'Curiosity', 'Leadership', 'Negotiation', 'Communication (generic)', 'Team']      1
# ['Creativity', 'Communication (generic)', 'Communication (written)']                             1
# ...

# %%
soft_skills_br['soft_skills'] = soft_skills_br['soft_skills'].apply(eval)

# calculate average number of soft skills mentioned in the job ads (from Brazil)
num_of_soft_skills_in_ad = []
for i, ss_list in enumerate(soft_skills_br["soft_skills"]):
  if ss_list[0] != "Not mention":
    num_of_soft_skills_in_ad.append(len(ss_list))

#print(sorted(num_of_soft_skills_in_ad))
print(f"The job adverstisement that lists the largest number of soft skills mentions {max(num_of_soft_skills_in_ad)} soft skills")
print(f"On average, job ads list {statistics.mean(num_of_soft_skills_in_ad)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-c42153adbbe1> in <cell line: 1>()
# ----> 1 soft_skills_br['soft_skills'] = soft_skills_br['soft_skills'].apply(eval)
#       2
#       3 # calculate average number of soft skills mentioned in the job ads
#       4 num_of_soft_skills_in_ad = []
#       5 for i, ss_list in enumerate(soft_skills_br["soft_skills"]):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4628         dtype: float64
#    4629         """
# -> 4630         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4631
#    4632     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1023
#    1024         # self.f is Callable
# -> 1025         return self.apply_standard()
#    1026
# ...
